# %% [markdown]
# ## Quiz 52: Solving Systems Three Ways

# %% [markdown]
# > 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > **ANSWER: B**

# %% [markdown]
# > 2.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > **ANSWER: C**

# %% [markdown]
# > 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ x + y = -2 \sim y = -x - 2 $$

# %% [markdown]
# $$ 4x - (-x - 2) = -3 $$

# %% [markdown]
# $$ 4x + x + 2 = -3 $$

# %% [markdown]
# $$ 5x + 2 = -3 $$

# %% [markdown]
# $$ 5x = -5 $$

# %% [markdown]
# $$ \boxed{x = -1} $$

# %% [markdown]
# $$ 4(-1) - y = -3 $$

# %% [markdown]
# $$ -4 - y = -3 $$

# %% [markdown]
# $$ -(-y = 1) \sim \boxed{y = -1} $$

# %% [markdown]
# > **ANSWER: C**

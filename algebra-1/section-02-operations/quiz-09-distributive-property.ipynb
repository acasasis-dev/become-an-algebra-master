# %% [markdown]
# ## Quiz 9: Distributive Property

# %% [markdown]
# > 1. Which of these represents the Distributive Property?
#
# ![image.png](attachment:image.png)
#
# The answer is **B**

# %% [markdown]
# > 2. Use the Distributive Property to expand the expression.
#
# \begin{gather*}
#     \frac{1}{2}(4x + 4) \\ \\
#
#     \frac{4x}{2} + \frac{4}{2} \\ \\
#
#     \boxed{2x + 2}
# \end{gather*}

# %% [markdown]
# > 3. Use the Distributive Property to expand the expression.
#
# \begin{gather*}
#     2x(3 + x^2) \\ \\
#
#     \boxed{6x + 2x^3}
# \end{gather*}

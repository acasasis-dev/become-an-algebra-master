# %% [markdown]
# ## Quiz 4: Commutative Property

# %% [markdown]
# > 1. Which of the equations is true based on the Commutative Property?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Which of the equations is true based on the Commutative Property?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Which of the equations is true based on Commutative Property of Multiplication?
#
# ![image.png](attachment:image.png)

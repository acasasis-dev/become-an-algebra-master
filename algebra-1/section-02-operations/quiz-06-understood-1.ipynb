# %% [markdown]
# ## Quiz 6: Understood 1

# %% [markdown]
# > 1. Choose an expression of equal value.
#
# \begin{gather*}
#     x \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)
#
# The answer is **B**
#
# \begin{gather*}
#     \frac{1x^1}{1} \\ \\
#
#     \frac{x^1}{1} \\
#     \frac{x}{1} \\ \\
#
#     \boxed{x}
# \end{gather*}

# %% [markdown]
# > 2. Simplify the expression.
#
# \begin{gather*}
#     1(1x + 1^1) - \frac{1}{1(-1x^1)} \\ \\
#
#     1x + 1^1 - \frac{1}{-1x^1} \\
#     x + 1 + \frac{1}{x^1} \\
#     x + 1 + \frac{1}{x} \\
#     \frac{x^2}{x} + \frac{x}{x} + \frac{1}{x} \\ \\
#     \boxed{\frac{x^2 + x + 1}{x}}
# \end{gather*}

# %% [markdown]
# > 3. Which of these expressions, if any, would not be equal to $xy$?
#
# ![image.png](attachment:image.png)
#
# The answer is **D**

# %% [markdown]
# ## Quiz 3: Associative Property

# %% [markdown]
# > 1. Which of these equations best represents the Associative Property of Addition?
#
# ![image.png](attachment:image.png)
#
# The answer is **A**

# %% [markdown]
# > 2. Which equation is true based on the Associative Property of Multiplication?
#
# ![image.png](attachment:image.png)
#
# The answer is **A**

# %% [markdown]
# > 3. Which equation shows the Associative Property of Addition?
#
# ![image.png](attachment:image.png)
#
# The answer is **D**

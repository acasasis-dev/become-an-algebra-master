# %% [markdown]
# ## Quiz 2: Identifying Multiplication

# %% [markdown]
# > 1. Which of these is multiplication?
#
# ![image.png](attachment:image.png)
#
# The answer is **D**

# %% [markdown]
# > 2. Simplify the expression.
#
# \begin{gather*}
#     (3 \times 2 \cdot 2)(4) \times 2 \\ \\
#
#     (6 \cdot 2)(4) \times 2 \\
#     (12)(4) \times 2 \\
#     48 \times 2 \\ \\
#
#     \boxed{96}
# \end{gather*}

# %% [markdown]
# > 3. Simplify the expression.
#
# \begin{gather*}
#     2(-3)(-5) \cdot 2 \times 4 \\ \\
#
#     -6(-5) \cdot 2 \times 4 \\
#     30 \cdot 2 \times 4 \\
#     60 \times 4 \\ \\
#
#     \boxed{240}
# \end{gather*}

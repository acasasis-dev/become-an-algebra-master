# %% [markdown]
# ## Quiz 5: Transitive Property

# %% [markdown]
# > 1. What does the Transitive Property tell us about the set of equations?
#
# \begin{gather*}
#     y = 4x - 2 \\
#     3z + 6 = y \\ \\
#
#     \boxed{3z + 6 = 4x - 2}
# \end{gather*}

# %% [markdown]
# > 2. What does the Transitive Property tell us about the set of equations?
#
# \begin{gather*}
#     3x = 2y - 5 \\
#     7z + 4 = 2y - 5 \\ \\
#
#     \boxed{3x = 7z + 4}
# \end{gather*}

# %% [markdown]
# > 3. Using the Transitive Property, choose the equation that would be the correct conclusion from the pair of equations.
#
# \begin{gather*}
#     w = r \\
#     r = b \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)
#
# The answer is **C**

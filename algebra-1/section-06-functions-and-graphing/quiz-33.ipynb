# %% [markdown]
# ## Quiz 33: Graphing linear equations

# %% [markdown]
# > 1. What is the y-intercept of the line

# %% [markdown]
# $$ y + 4 = -5(x - 2) $$

# %% [markdown]
# $$ y + 4 = -5x + 10 $$

# %% [markdown]
# $$ y = -5x + 10 -4 = -5x + \boxed{6} $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. **Answer: B.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. **Answer: A.**

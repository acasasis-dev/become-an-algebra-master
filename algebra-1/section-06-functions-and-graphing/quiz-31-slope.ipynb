# %% [markdown]
# ## Quiz 31: Slope

# %% [markdown]
# > 1. What is the slope of the line?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. What is the slope of the line that passes thru the points $(3 -2)$ and $(-7, 3)$?

# %% [markdown]
# > 3. If each answer choice gives a pair of points in a line, which line has the steepest slope?
#
# ![image.png](attachment:image.png)

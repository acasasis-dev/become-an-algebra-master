# %% [markdown]
# ## Quiz 36: Testing for Functions

# %% [markdown]
# > 1. Does the equation represent a function?
#
# \begin{gather*}
#     2x^2 + 2y^2 = 18 \\ \\
# \end{gather*}
#
# No, since even having $x = 0$, $y$ will result with $\pm 3$ which 2 outputs in just 1 $x$

# %% [markdown]
# > 2. Which of these could represent a function?
#
# ![image.png](attachment:image.png)
#
# The answer is **D** as it's the only one with 1 unique outputs from 1 unique inputs

# %% [markdown]
# > 3. The graph shows eight points that define a relation between $x$ and $y$. Identify the pair of points which prove that the relation is not a function.
#
# ![image.png](attachment:image.png)
#
# Points that proves that this is not a function are $(2, 1)$ and $(2, 5)$

# %% [markdown]
# ## Quiz 30: Cartesian Coordinate System

# %% [markdown]
# > 1. Graph $(1, 2)$ in the Cartesian coordinate system.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Which point lies in Quadrant II of the Cartesian plane?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Which group of points contains a point not plotted in the plane?
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

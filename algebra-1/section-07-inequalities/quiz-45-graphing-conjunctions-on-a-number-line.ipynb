# %% [markdown]
# ## Quiz 45: Graphing Conjunctions On A Number Line

# %% [markdown]
# > 1. Graph the conjunction $-1 < x 5$.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Graph the conjunction $2 > x \ge -4$.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Graph the conjunction of the inequalities.
#
# \begin{gather*}
#     -6x + 11 > -7 \\
#     5x - 6 \ge -26 \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Quiz 44: Graphing Disjunctions On A Number Line

# %% [markdown]
# > 1. Graph the disjunction.
#
# $x < - 2$ or $x > 4$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Graph the disjunction.
#
# $2x - 5 \ge 7$ or $3(x - 2) < 6$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Graph the disjunction.
#
# $2(x - 2) + 3 > 1$ or $2(4 - x) \le x - 1$
#
# ![image.png](attachment:image.png)

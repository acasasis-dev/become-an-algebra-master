# %% [markdown]
# ## Quiz 46: Graphing Inequalities In A Plane

# %% [markdown]
# > 1. Graph the linear inequality in the Cartesian coordinate system.
#
# $y > 2$
#
# ![image.png](attachment:image.png)
#
# The answer is **C**

# %% [markdown]
# > 2. Graph the linear inequality in the Cartesian coordinate system.
#
# $y \ge -2x + 1$
#
# ![image.png](attachment:image.png)
#
# The answer is **A**

# %% [markdown]
# > 3. Graph the linear inequality in the Cartesian coordinate system.
#
# $y \le 2x + 4$
#
# ![image.png](attachment:image.png)
#
# The answer is **D**

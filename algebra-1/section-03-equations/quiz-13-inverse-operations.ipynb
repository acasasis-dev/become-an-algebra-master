# %% [markdown]
# ## Quiz 13: Inverse Operations

# %% [markdown]
# > 1. Choose the pair of equations that represents inverse operations.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Choose the pair of equations that represents inverse operations.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Each choice below shows an equation before a change is made and then after the change is made. Three of them are wrong. Which one correctly shows the result of an inverse operation?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Quiz 96: Parallel and Perpendicular Lines

# %% [markdown]
# > 1. What can we say about the slopes of these lines?
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > 2. Which line is parallel to the given line?
#
# \begin{gather*}
#     y = x + 3
# \end{gather*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Which line is perpendicular to the given line?
#
# \begin{gather*}
#     y = 2x + 3 \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

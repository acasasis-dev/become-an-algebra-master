# %% [markdown]
# ## Quiz 94: Systems With Non-Linear Equations

# %% [markdown]
# > 1. Use any method to find the solution(s) to the system of equations.
#
# \begin{gather*}
#     x^2 + y^2 = 25 \\
#     3x - y = 5 \\ \\
#
#     3x - y = 5 \\
#     y = 3x - 5 \\ \\
#
#     x^2 + (3x - 5)^2 = 25 \\
#     x^2 + (3x - 5)(3x - 5) = 25 \\
#     x^2 + 9x^2 - 15x - 15x + 25 = 25 \\
#     10x^2 - 30x + 25 = 25 \\
#     \frac{10x^2 - 30x + 25 = 25}{5} \\
#     2x^2 - 6x + 5 = 5 \\
#     2x^2 - 6x = 5 - 5 \\
#     2x^2 - 6x = 0 \\
#     x(2x - 6) = 0
#     \boxed{x = 0} \\
#     2x - 6 = 0 \\
#     2x = 6 \\
#     \frac{2x = 6}{2} \\
#     \boxed{x = 3} \\ \\
#
#     y = 3x - 5 \\
#     y = 3(0) - 5 \\
#     y = 0 - 5 \\
#     \boxed{y = -5} \\ \\
#
#     y = 3x - 5 \\
#     y = 3(3) - 5 \\
#     y = 9 - 5 \\
#     \boxed{y = 4} \\ \\
#
#     \boxed{(x, y) = (0, -5)} \\
#     \boxed{(x, y) = (3, 4)} \\ \\
#
#     \textbf{CHECKING} \\
#     3x - y = 5 \\
#     3(0) - (-5) = 5 \\
#     0 + 5 = 5 \\
#     5 = 5 \\ \\
#
#     3x - y = 5 \\
#     3(3) - (4) = 5 \\
#     9 - 4 = 5 \\
#     5 = 5
# \end{gather*}

# %% [markdown]
# > 2. Solve the system for $x$ and $y$.
#
# \begin{gather*}
#     (x - 2)^2 + y^2 = 4 \\
#     \frac{x}{2} - y = -1 \\ \\
#
#     \frac{x}{2} - y = -1 \\
#     y = \frac{x}{2} + 1 \\ \\
#
#     (x - 2)^2 + y^2 = 4 \\
#     (x - 2)^2 + (\frac{x}{2} + 1)^2 = 4 \\
#     (x - 2)(x - 2) + (\frac{x}{2} + 1)(\frac{x}{2} + 1) = 4 \\
#     x^2 - 2x - 2x + 4 + \frac{x^2}{4} + \frac{x}{2} + \frac{x}{2} + 1 = 4 \\
#     x^2 - 4x + 4 + \frac{x^2}{4} + x + 1 - 4 = 0 \\
#     x^2 - 3x + \frac{x^2}{4} + 1 = 0 \\
#     4(x^2 - 3x + \frac{x^2}{4} + 1 = 0) \\
#     4x^2 - 12x + x^2 + 4 = 0 \\
#     5x^2 - 12x + 4 = 0 \\
#     5x^2 - 10x - 2x + 4 = 0 \\
#     (5x^2 - 10x) - (2x + 4) = 0 \\
#     5x(x - 2) - 2(x - 2) = 0 \\
#     (5x - 2)(x - 2) = 0 \\ \\
#
#     5x - 2 = 0 \\
#     5x = 2 \\
#     \frac{5x = 2}{5} \\
#     \boxed{x = \frac{2}{5}} \\ \\
#
#     x - 2 = 0 \\
#     \boxed{x = 2} \\ \\
#
#     y = \frac{x}{2} + 1 \\
#     y = \frac{\frac{2}{5}}{2} + 1 \\
#     y = (\frac{2}{5} \cdot \frac{1}{2}) + 1 \\
#     y = \frac{2}{10} + 1 \\
#     y = \frac{1}{5} + 1 \\
#     y = \frac{1}{5} + \frac{5}{5} \\
#     \boxed{y = \frac{6}{5}} \\ \\
#
#     y = \frac{x}{2} + 1 \\
#     y = \frac{2}{2} + 1 \\
#     y = 1 + 1 \\
#     \boxed{y = 2} \\ \\
#
#     \boxed{(x, y) = (\frac{2}{5}, \frac{6}{5})} \\
#     \boxed{(x, y) = (2, 2)} \\ \\
#
#     \textbf{CHECKING} \\
#     \frac{x}{2} - y = -1 \\
#     \frac{(\frac{2}{5})}{2} - (\frac{6}{5}) = -1 \\
#     (\frac{2}{5} \cdot \frac{1}{2}) - (\frac{6}{5}) = -1 \\
#     \frac{2}{10} - \frac{6}{5} = -1 \\
#     \frac{2}{10} - \frac{12}{10} = -1 \\
#     -\frac{10}{10} = -1 \\
#     -1 = -1 \\ \\
#
#     \frac{x}{2} - y = -1 \\
#     \frac{(2)}{2} - (2) = -1 \\
#     1 - 2 = -1 \\
#     -1 = -1
# \end{gather*}

# %% [markdown]
# > 3. Solve the system for $x$ and $y$.
#
# \begin{gather*}
#     2x^2 - 12x - y + 19 = 0 \\
#     2x + y = 11 \\ \\
#
#     2x + y = 11 \\
#     y = 11 - 2x \\ \\
#
#     2x^2 - 12x - y + 19 = 0 \\
#     2x^2 - 12x - (11 - 2x) + 19 = 0 \\
#     2x^2 - 12x - 11 + 2x + 19 = 0 \\
#     2x^2 - 10x + 8 = 0 \\
#     \frac{2x^2 - 10x + 8 = 0}{2} \\
#     x^2 - 5x + 4 = 0 \\
#     (x - 4)(x - 1) = 0 \\ \\
#
#     x - 4 = 0 \\
#     \boxed{x = 4} \\ \\
#
#     x - 1 = 0 \\
#     \boxed{x = 1} \\ \\
#
#     y = 11 - 2x \\
#     y = 11 - 2(4) \\
#     y = 11 - 8 \\
#     \boxed{y = 3} \\ \\
#
#     y = 11 - 2x \\
#     y = 11 - 2(1) \\
#     y = 11 - 2 \\
#     \boxed{y = 9} \\ \\
#
#     \boxed{(x, y) = (4, 3)} \\
#     \boxed{(x, y) = (1, 9)} \\ \\
#
#     \textbf{CHECKING} \\
#     2x + y = 11 \\
#     2(4) + (3) = 11 \\
#     8 + 3 = 11 \\
#     11 = 11 \\ \\
#
#     2x + y = 11 \\
#     2(1) + (9) = 11 \\
#     2 + 9 = 11 \\
#     11 = 11
# \end{gather*}

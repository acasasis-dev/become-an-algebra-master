# %% [markdown]
# ## Quiz 93: Age Word Problems

# %% [markdown]
# > 1. $20$ years ago, Beth's age was $6$ years greater than twice Chris' age. $6$ years ago, Chris was $\frac{3}{5}$ as old as Beth. How old are they now?
#
# \begin{gather*}
#     B - 20 = 2(C - 20) + 6 \\ \\
#     B - 20 = 2C - 40 + 6 \\
#     B = 2C - 40 + 20 + 6 \\
#     B = 2C - 20 + 6 \\
#     B = 2C - 14 \\ \\
#
#     \frac{3}{5}(B - 6) = C - 6 \\
#     \frac{3}{5}B - \frac{18}{5} = C - 6 \\
#     \frac{3}{5}B = C - 6 + \frac{18}{5} \\
#     \frac{3}{5}B = C - \frac{30}{5} + \frac{18}{5} \\
#     \frac{3}{5}B = C - \frac{12}{5} \\
#     \frac{5}{3}(\frac{3}{5}B = C - \frac{12}{5}) \\
#     B = \frac{5}{3}C - \frac{60}{15} \\
#     B = \frac{5}{3}C - 4 \\ \\
#
#     \frac{5}{3}C - 4 = 2C - 14 \\
#     14 - 4 = 2C - \frac{5}{3}C \\
#     10 = \frac{6}{3}C - \frac{5}{3}C \\
#     10 = \frac{1}{3}C \\
#     3(10 = \frac{1}{3}C) \\
#     \boxed{C = 30} \\ \\
#
#     B - 20 = 2((30) - 20) + 6 \\
#     B - 20 = 60 - 40 + 6 \\
#     B = 60 - 40 + 6 + 20 \\
#     \boxed{B = 46} \\ \\
#
#     \textbf{CHECKING} \\
#     (46) - 20 = 2((30) - 20) + 6 \\
#     26 = 60 - 40 + 6 \\
#     26 = 26 \\ \\
#
#     \frac{3}{5}((46) - 6) = (30) - 6 \\
#     \frac{3}{5}(40) = 24 \\
#     \frac{120}{5} = 24 \\
#     24 = 24
# \end{gather*}

# %% [markdown]
# > 2. Jordan is $16$ years older than Ryan. In $6$ years, Jordan will be twice as old as Ryan. How old is Jordan now?
#
# \begin{gather*}
#     J = R + 16 \\ \\
#
#     J + 6 = 2(R + 6) \\
#     J + 6 = 2R + 12 \\
#     J = 2R + 12 - 6 \\
#     J = 2R + 6 \\ \\
#
#     2R + 6 = R + 16 \\
#     2R - R = 16 - 6 \\
#     \boxed{R = 10} \\ \\
#
#     J = R + 16 \\
#     J = (10) + 16 \\
#     \boxed{J = 26} \\ \\
#
#     \textbf{CHECKING} \\
#     J = R + 16 \\
#     (26) = (10) + 16 \\
#     26 = 26 \\ \\
#
#     J + 6 = 2(R + 6) \\
#     (26) + 6 = 2((10) + 6) \\
#     32 = 20 + 12 \\
#     32 = 32
# \end{gather*}

# %% [markdown]
# > 3. Claire is 8 years older than Max. 4 years ago, she was $3$ times as old as Max. How old is Max now?
#
# \begin{gather*}
#     C = M + 8 \\ \\
#
#     C - 4 = 3(M - 4) \\
#     C - 4 = 3M - 12 \\
#     C = 3M - 12 + 4 \\
#     C = 3M - 8 \\ \\
#
#     3M - 8 = M + 8 \\
#     3M - M = 8 + 8 \\
#     2M = 16 \\
#     \frac{2M = 16}{2} \\
#     \boxed{M = 8} \\ \\
#
#     C = M + 8 \\
#     C = (8) + 8 \\
#     \boxed{C = 16} \\ \\
#
#     \textbf{CHECKING} \\
#     C = M + 8 \\
#     (16) = (8) + 8 \\
#     16 = 16 \\ \\
#
#     C - 4 = 3(M - 4) \\
#     (16) - 4 = 3((8) - 4) \\
#     12 = 3(4) \\
#     12 = 12
# \end{gather*}

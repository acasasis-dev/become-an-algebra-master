# %% [markdown]
# ## Quiz 123: Graphing Log Functions

# %% [markdown]
# > 1. Will the graph of the function have a vertical asymptote or a horizontal asymptote?
#
# \begin{gather*}
#     y = \log_2(x + 2) \\ \\
# \end{gather*}

# %% [markdown]
# > 2. Sketch the graph of the logaritmic function.
#
# \begin{gather*}
#     y = -\frac{1}{3}\log_3(x + 1) \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Sketch the graph of the logaritmic function.
#
# \begin{gather*}
#     y = \log_5x \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

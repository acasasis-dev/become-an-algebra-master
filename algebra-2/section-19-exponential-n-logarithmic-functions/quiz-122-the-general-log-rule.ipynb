# %% [markdown]
# ## Quiz 122: The General Log Rule

# %% [markdown]
# > 1. Write the inverse of the function
#
# \begin{gather*}
#     \log_7(x) = y \\ \\
# \end{gather*}

# %% [markdown]
# > 2. The table shows points of the graph of an exponential function. Choose the set of points that will be on the graph of its inverse.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. The graph shown represents an invertible function and passes through the points $(1,0), (4,2), (8,3),$ and $(16,4)$. Which is the graph of its inverse.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Quiz 121: Graphing Transformations of Exponential Functions

# %% [markdown]
# > 1. Sketch the graph of the exponential function.
#
# \begin{gather*}
#     y = 5^{x - 4} + 3 \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Sketch the graph of the exponential function.
#
# \begin{gather*}
#     y = 7^{-x} + 2 \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Sketch the graph of the exponential function.
#
# \begin{gather*}
#     y = -2^{x + 5} \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Quiz 124: Graphing Transformations of Log Functions

# %% [markdown]
# > 1. Will the graph of the function have a vertical or a horizontal asymptote?
#
# \begin{gather*}
#     y = \log_2(x - 7) \\ \\
# \end{gather*}

# %% [markdown]
# > 2. Use transformations to sketch the graph of $y = -\ln(-x + 3)$.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Given the graph of $y = \log_2(x)$, use transformations to sketch the graph of $y = 2\log_2(x - 2)$.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

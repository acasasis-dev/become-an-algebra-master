# %% [markdown]
# ## Quiz 114: Common Bases and Restricted Values

# %% [markdown]
# > 1. Which answer choice describes an equivalent value?
#
# \begin{gather*}
#     \log(1000) \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Which answer choice describes an equivalent value?
#
# \begin{gather*}
#     log_e(x) \\ \\
# \end{gather*}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Which is true about the base of a logarithm?
#
# ![image.png](attachment:image.png)

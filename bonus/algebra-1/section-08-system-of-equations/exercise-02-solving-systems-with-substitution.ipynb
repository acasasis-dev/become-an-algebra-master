# %% [markdown]
# ## Exercise 2: Solving System With Substitution

# %% [markdown]
# > 1. Find the unique solution to the system of equations.
#
# \begin{gather*}
#     -x + 2y = 6 \\
#     3x = y - 10 \\ \\
#
#     x = 2y - 6 \\
#     3(2y - 6) = y - 10 \\
#     6y - 18 = y - 10 \\
#     6y - y = 18 - 10 \\
#     5y = 8 \\
#     \frac{5y = 8}{5} \\
#     \boxed{y = \frac{8}{5}} \\ \\
#
#     x = 2y - 6 \\
#     x = 2(\frac{8}{5}) - 6 \\
#     x = \frac{16}{5} - \frac{30}{5} \\
#     \boxed{x = -\frac{14}{5}} \\ \\
#
#     \textbf{CHECKING} \\
#     -x + 2y = 6 \\
#     -(-\frac{14}{5}) + 2(\frac{8}{5}) = 6 \\
#     \frac{14}{5} + \frac{16}{5} = 6 \\
#     \frac{30}{5} = 6 \\
#     6 = 6 \\ \\
#
#     3x = y - 10 \\
#     3(-\frac{14}{5}) = (\frac{8}{5}) - 10 \\
#     -\frac{42}{5} = \frac{8}{5} - \frac{50}{5} \\
#     -\frac{42}{5} = -\frac{42}{5}
# \end{gather*}

# %% [markdown]
# > 2. What is the easiest variable to get by itself? Set up but do not solve
# the substitution.
#
# \begin{gather*}
#     2y - x = 7 \\
#     3x = 9 - 18y \\ \\
#
#     x = 2y - 7 \\
#     3(2y - 7) = 9 - 18y \\
#     6y - 21 = 9 - 18y \\
#     6y + 18y = 21 + 9 \\
#     24y = 30 \\
#     \frac{24y = 30}{24} \\
#     y = \frac{30}{24} \\
#     \boxed{y = \frac{5}{4}} \\ \\
#
#     x = 2(\frac{5}{4}) - 7 \\
#     x = \frac{10}{4} - 7 \\
#     x = \frac{5}{2} - \frac{14}{2} \\
#     \boxed{x = -\frac{9}{2}} \\ \\
#
#     \textbf{CHECKING} \\
#     2y - x = 7 \\
#     2(\frac{5}{4}) - (-\frac{9}{2}) = 7 \\
#     \frac{10}{4} + \frac{9}{2} = 7 \\
#     \frac{10}{4} + \frac{18}{4} = 7 \\
#     \frac{28}{4} = 7 \\
#     7 = 7 \\ \\
#
#     3x = 9 - 18y \\
#     3(-\frac{9}{2}) = 9 - 18(\frac{5}{4}) \\
#     -\frac{27}{2} = 9 - \frac{90}{4} \\
#     -\frac{27}{2} = \frac{36}{4} - \frac{90}{4} \\
#     -\frac{27}{2} = -\frac{54}{4} \\
#     -\frac{54}{4} = -\frac{54}{4}
# \end{gather*}

# %% [markdown]
# > 3. Find the unique solution to the system of equations.
#
# \begin{gather*}
#     -5x + y = 8 \\
#     y = 3x - 8 \\ \\
#
#     -5x + (3x - 8) = 8 \\
#     -5x + 3x - 8 = 8 \\
#     -2x - 8 = 8 \\
#     -2x = 8 + 8 \\
#     -2x = 16 \\
#     \frac{-2x = 16}{-2} \\
#     \boxed{x = -8} \\ \\
#
#     y = 3(-8) - 8 \\
#     y = -24 - 8 \\
#     \boxed{y = -32} \\ \\
#
#     \textbf{CHECKING} \\
#     -5x + y = 8 \\
#     -5(-8) + (-32) = 8 \\
#     40 - 32 = 8 \\
#     8 = 8 \\ \\
#
#     y = 3x - 8 \\
#     (-32) = 3(-8) - 8 \\
#     -32 = -24 - 8 \\
#     -32 = -32
# \end{gather*}

# %% [markdown]
# > 4. Find the unique solution to the system of equations.
#
# \begin{gather*}
#     3 - y = 2x \\
#     -4x + 10 = 2y \\ \\
#
#     y = 3 - 2x \\
#     -4x + 10 = 2(3 - 2x) \\
#     -4x + 10 = 6 - 4x \\
#     -4x + 4x = 6 - 10 \\
#     0x \ne -4
# \end{gather*}
#
# No Solution

# %% [markdown]
# > 5. What went wrong if a substitution was made in the system and the
# result was $2x − 2 − x = 7$?
#
# \begin{gather*}
#     y = x - 2 \\
#     2y - x = 7 \\ \\
# \end{gather*}
#
# Solver did not distribute $2$ to $x - 2$, result should be $2x - 4 - x = 7$

# %% [markdown]
# > 6. Find the unique solution to the system of equations.
#
# \begin{gather*}
#     5y = 6 - 2x \\
#     6x + 15y = 18 \\ \\
#
#     2x = 6 - 5y \\
#     \frac{2x = 6 - 5y}{2} \\
#     x = 3 - \frac{5}{2}y \\ \\
#
#     6(3 - \frac{5}{2}y) + 15y = 18 \\
#     18 - \frac{30}{2}y + 15y = 18 \\
#     18 - 15y + 15y = 18 \\
#     -15y + 15y = 18 - 18 \\
#     0 = 0
# \end{gather*}
#
# Infinite number of solutions

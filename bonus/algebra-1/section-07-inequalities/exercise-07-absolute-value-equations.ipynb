# %% [markdown]
# ## Exercise 7: Absolute Value Equations

# %% [markdown]
# > 1. Solve $|3 − x | = 1$.
#
# \begin{gather*}
#     3 - x = 1 \\
#     x = 3 - 1 \\
#     \boxed{x = 2} \\ \\
#
#     3 - x = -1 \\
#     x = 3 + 1 \\
#     \boxed{x = 4} \\ \\
#
#     \textbf{CHECKING} \\
#     x = 2 \\
#     |3 - (2)| = 1 \\
#     |1| = 1 \\
#     1 = 1 \\ \\
#
#     x = 4 \\
#     |3 - (4)| = 1 \\
#     |-1| = 1 \\
#     1 = 1
# \end{gather*}

# %% [markdown]
# > 2. Solve $|4x − 8| = 3x − 6$.
#
# \begin{gather*}
#     4x - 8 = 3x - 6 \\
#     4x - 3x = 8 - 6 \\
#     \boxed{x = 2} \\ \\
#
#     4x - 8 = -(3x - 6) \\
#     4x - 8 = -3x + 6 \\
#     4x + 3x = 6 + 8 \\
#     7x = 14 \\
#     \frac{7x = 14}{7} \\
#     \boxed{x = 2} \\ \\
#
#     \textbf{CHECKING} \\
#     x = 2 \\
#     |4(2) - 8| = 3(2) - 6 \\
#     |8 - 8| = 6 - 6 \\
#     0 = 0
# \end{gather*}

# %% [markdown]
# > 3. Solve $|2x − 2| = x − 6$.
#
# \begin{gather*}
#     2x - 2 = x - 6 \\
#     2x - x = 2 - 6 \\
#     x = -4 \\ \\
#
#     2x - 2 = -(x - 6) \\
#     2x - 2 = -x + 6 \\
#     2x + x = 6 + 2 \\
#     3x = 8 \\
#     \frac{3x = 8}{3} \\
#     x = \frac{8}{3} \\ \\
#
#     \textbf{CHECKING} \\
#     x = -4 \\
#     |2(-4) - 2| = (-4) - 6 \\
#     |-8 - 2| = -10 \\
#     |-10| = -10 \\
#     10 \ne -10 \\ \\
#
#     x = \frac{8}{3} \\
#     |2(\frac{8}{3}) - 2| = (\frac{8}{3}) - 6 \\
#     |\frac{16}{3} - \frac{6}{3}| = \frac{8}{3} - \frac{18}{3} \\
#     |\frac{10}{3}| = -\frac{10}{3} \\
#     \frac{10}{3} \ne -\frac{10}{3}
# \end{gather*}

# %% [markdown]
# > 4. Solve $|3x + 1| + x = 1$.
#
# \begin{gather*}
#     3x + 1 = 1 - x \\
#     3x + x = 1 - 1
#     4x = 0 \\
#     \boxed{x = 0} \\ \\
#
#     3x + 1 = -(1 - x) \\
#     3x + 1 = -1 + x \\
#     3x - x = -1 - 1 \\
#     2x = -2 \\
#     \frac{2x = -2}{2} \\
#     \boxed{x = -1} \\ \\
#
#     \textbf{CHECKING} \\
#     x = 0 \\
#     |3(0) + 1| + (0) = 1 \\
#     |1| = 1 \\
#     1 = 1 \\ \\
#
#     x = -1 \\
#     |3(-1) + 1| + (-1) = 1 \\
#     |-3 + 1| - 1 = 1 \\
#     |-2| - 1 = 1 \\
#     2 - 1 = 1 \\
#     1 = 1
# \end{gather*}

# %% [markdown]
# > 5. Solve $|2x + 5| = 3x + 6$.
#
# \begin{gather*}
#     2x + 5 = 3x + 6 \\
#     3x - 2x = 5 - 6 \\
#     \boxed{x = -1} \\ \\
#
#     2x + 5 = -(3x + 6) \\
#     2x + 5 = -3x - 6 \\
#     2x + 3x = -6 - 5 \\
#     5x = -11 \\
#     \frac{5x = -11}{5} \\
#     x = -\frac{11}{5} \\ \\
#
#     \textbf{CHECKING} \\
#     x = -1 \\
#     |2(-1) + 5| = 3(-1) + 6 \\
#     |-2 + 5| = -3 + 6 \\
#     |3| = 3 \\
#     3 = 3 \\ \\
#
#     x = -\frac{11}{5} \\
#     |2(-\frac{11}{5}) + 5| = 3(-\frac{11}{5}) + 6 \\
#     |-\frac{22}{5} + \frac{25}{5}| = -\frac{33}{5} + \frac{30}{5} \\
#     |\frac{3}{5}| = -\frac{3}{5} \\
#     \frac{3}{5} \ne -\frac{3}{5}
# \end{gather*}

# %% [markdown]
# > 6. Solve $|3x + 2| = |3x + 4|$.
#
# \begin{gather*}
#     3x + 2 = 3x + 4 \\
#     3x - 3x = 4 - 2 \\
#     0 \ne 2 \\ \\
#
#     3x + 2 = -(3x + 4) \\
#     3x + 2 = -3x - 4  \\
#     3x + 3x = -4 - 2 \\
#     6x = -6 \\
#     \frac{6x = -6}{6} \\
#     \boxed{x = -1} \\ \\
#
#     \textbf{CHECKING} \\
#     x = -1 \\
#     |3(-1) + 2| = |3(-1) + 4| \\
#     |-3 + 2| = |-3 + 4| \\
#     |-1| = |1| \\
#     1 = 1
# \end{gather*}

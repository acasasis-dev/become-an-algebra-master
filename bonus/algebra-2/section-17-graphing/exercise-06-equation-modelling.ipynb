# %% [markdown]
# ## Exercise 6: Equation Modelling

# %% [markdown]
# > 1. A car and a truck were driven for a week. The car traveled $75$ miles
# more than the truck. Each vehicle had different fuel mileage. Write an
# equation using $t$ (where $t$ is the number of miles the truck traveled) to
# calculate the number of gallons $g$, used during the week.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#     c = t + 75 \\
#
#     g = \frac{t + 75}{28} + \frac{t}{14} \\
#     g = \frac{t + 75}{28} + \frac{2}{2}\left(\frac{t}{14}\right) \\
#     g = \frac{t + 75 + 2t}{28} \\
#     \boxed{g = \frac{3t + 75}{28}}
# \end{gather*}

# %% [markdown]
# > 2. A baseball is thrown at a speed of $21$ $ft/s$ straight down from a high
# platform. The distance it travels can be calculated using $D = 16t^2 + 21t$,
# where $t$ is the amount of time in seconds that it’s been falling. The average
# speed of any object can be calculated using $V = D/t$. Write an equation
# giving the time of the fall in terms of $V$.

# %% [markdown]
# \begin{gather*}
#     V = \frac{D}{t} \\
#     V = \frac{16t^2 + 21t}{t} \\
#     V = 16t + 21 \\
#     16t = V - 21 \\
#     \frac{16t = V - 21}{16} \\
#     \boxed{t = \frac{V - 21}{16}}
# \end{gather*}

# %% [markdown]
# > 3. A rock is thrown at a speed of $8$ $ft/s$ straight down from a high
# platform. The distance it travels can be calculated using $D = 16t^2 + 8t$,
# where $t$ is the amount of time in seconds that it’s been falling. The average
# speed of any object can be calculated using $V = D/t$. Write an equation
# giving the time of the fall in terms of $V$.

# %% [markdown]
# \begin{gather*}
#     V = \frac{D}{t} \\
#     V = \frac{16t^2 + 8t}{t} \\
#     V = 16t + 8 \\
#     16t = V - 8 \\
#     \frac{16t = V - 8}{16} \\
#     \boxed{t = \frac{V - 8}{16}}
# \end{gather*}

# %% [markdown]
# > 4. Managers at a company are each paid $\$45\text{,}000$ in base salary. The
# company’s owner wants to divide $\$162\text{,}000$ in annual bonus money evenly
# among the managers. Write an expression, in terms of the number of
# mangers $m$, that gives the amount a each manager earns per month.

# %% [markdown]
# > 5. Managers at a company are each paid $\$37\text{,}800$ in base salary. The
# company’s owner wants to divide $\$102\text{,}000$ in annual bonus money evenly
# among the managers. Write an expression, in terms of the number of
# mangers $m$, that gives the amount $a$ each manager earns per month.

# %% [markdown]
# > 6. The Jones and Anderson family go on vacation together with each
# family driving in their own car. The Anderson family travels $50$ miles further
# than the Jones family. Each family averages $65$ mph on the trip. Write an
# equation using $D_a$ (where $D_a$ is the total miles the Anderson family drove)
# to calculate the total time $T$ both families spent driving to their destination.
#
# ![image.png](attachment:image.png)

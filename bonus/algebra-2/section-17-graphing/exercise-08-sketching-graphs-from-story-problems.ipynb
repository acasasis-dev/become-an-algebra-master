# %% [markdown]
# ## Exercise 8: Sketching Graphs From Story Problems

# %% [markdown]
# > 1. A horse is practicing for a race. The graph shows the horse’s speed
# over time. Write a possible story to go with the graph.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. A scuba diver takes a dive to explore the ocean. The graph below
# shows the diver’s elevation over time. Write a possible story to go with the
# graph.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. Janet delivers packages and get paid an hourly rate in addition to $\$1$
# for every package she delivers. The graph shows Janet’s pay over the
# course of the day. Write a possible story to go with the graph.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 4. A plane takes off and then cruises at $30\text{,}000$ feet for several hours
# before rising in elevation to $35\text{,}000$ feet to avoid turbulence for the last few
# hours. The plane then reaches its destination and lands. Sketch a graph
# representing the situation.

# %% [markdown]
# > 5. The temperature throughout a summer day starts at $65\degree F$ at 6:00 a.m..
# Over the next few hours the temperature rises steadily until it reaches $85\degree F$
# at 1:00 p.m.. At 1:15 p.m., a rainstorm begins and cools the temperature
# down to $75\degree F$. The temperature then steadily decreases until it reaches $70\degree
# F$ at 9:00 p.m.. Sketch a graph representing the situation.

# %% [markdown]
# > 6. Brett goes for a hike up a mountain. He starts hiking up steadily for
# several hours with two stops for water. Then Brett stops for an hour to eat
# lunch and rest. He then continues up the mountain, summits, and spends a
# little time at the top of the mountain before climbing down. Sketch a graph
# representing Brett’s elevation over time.

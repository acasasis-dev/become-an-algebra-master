# %% [markdown]
# ## Exercise 4: Graphing Circles

# %% [markdown]
# > 1. Find the equation of the circle.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Graph the circle $(x - 1)^2 + (y - 2)^2 = 4$.

# %% [markdown]
# > 3. Graph the circle $x^2 + (y - 3)^2 = 16$.

# %% [markdown]
# > 4. Graph the circle $x^2 + y^2 + 2x + 2y - 14 = 0$.

# %% [markdown]
# > 5. Graph the circle $x^2 + y^2 - 8x - 4y + 11 = 0$.

# %% [markdown]
# > 6. Graph the circle $x^2 + y^2 + 6x - 8y - 11 = 0$.

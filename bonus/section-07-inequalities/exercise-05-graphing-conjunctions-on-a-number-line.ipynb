# %% [markdown]
# ## Exercise 5: Graphing Conjunctions On A Number Line

# %% [markdown]
# > 1. Graph the conjunction of the inequalities $3(x − 4) < x − 2$ and
# $−2(x − 6) + 3 \ge 5$.

# %% [markdown]
# > 2. Graph the conjunction.
#
# $−8 \le − 2x < 10$

# %% [markdown]
# > 3. What’s wrong with the graph of the conjunction?
#
# $x \le 3$ and $x > − 4$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 4. What’s wrong with the graph of the conjunction?
#
# $x \le 3$ and $x \ne 0$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 5. What’s wrong with the graph of the conjunction?
#
# $x < −2$ and $x > −5$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 6. Graph the conjunction.
#
# $2x − 1 \ge 3$ and $−x \ge − 9$

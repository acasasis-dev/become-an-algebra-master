# %% [markdown]
# ## Exercise 4: Graphing Disjunctions On A Number Line

# %% [markdown]
# > 1. What’s wrong with the graph of the disjunction?
#
# $2x \le 4$ or $x − 5 > 3$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. Graph the disjunction.
#
# $x + 2 \ge 2x + 3$ or $x − 5 \ge 0$

# %% [markdown]
# > 3. Graph the disjunction of the inequalities.
#
# $2(x − 3) + x < 2x + 1$ or $2(x − 1) − 6 > 6$

# %% [markdown]
# > 4. What’s wrong with the graph of the disjunction?
#
# $−x + 3 < 5$ or $−2(x + 2) \ge 2$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 5. Graph the disjunction.
#
# $2x + 3 \ge 3$ or $2x + 5 < x$

# %% [markdown]
# > 6. Graph the disjunction.
#
# $−2x + 5 \ge − 1$ or $x − 6 > − 2$

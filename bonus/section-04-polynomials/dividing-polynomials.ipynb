# %% [markdown]
# ## Dividing Polynomials

# %% [markdown]
# > 1. Simplify the expression using the polynomial long division.
#
# \begin{gather*}
#     (3x^3 - x^2 + 5) \div (x + 2) \\ \\
# \end{gather*}

# %% [markdown]
# > 2. What went wrong in setting up the long division problem?
#
# \begin{gather*}
#     (5x^4 - 3x^2 + x - 2) \div (x^2 + 1) \\
#     5x^4 - 3x^2 + x - 2 \ \overline{|x^2 + 1} \\ \\
# \end{gather*}

# %% [markdown]
# > 3. Express the full solution of the polynomial long division.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 4. Simplify the expression using polynomial long division.
#
# \begin{gather*}
#     (2x^5 - 3x^3 + x^2 + 4x - 1) \div (x^2 + 2) \\ \\
# \end{gather*}

# %% [markdown]
# > 5. Simplify the expression using polynomial long division.
#
# \begin{gather*}
#     \frac{x^5 - x^3 + 4x^2 - x + 6}{2x^3 - 5} \\ \\
# \end{gather*}

# %% [markdown]
# > 6. Simplify the expression using polynomial long division.
#
# \begin{gather*}
#     (3x^2 + 2x + 5) \div (3x + 5) \\ \\
# \end{gather*}

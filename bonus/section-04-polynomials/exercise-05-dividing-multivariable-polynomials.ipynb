# %% [markdown]
# ## Dividing MultiVariable Polynomials

# %% [markdown]
# > 1. Find the quotient.
#
# \begin{gather*}
#     \frac{3x^2 + 6xy - 2y^2}{x - 2y} \\ \\
# \end{gather*}

# %% [markdown]
# > 2. Identify the quotient, remainder, and divisor.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 3. How should we rewrite the expression before starting the long division?
#
# \begin{gather*}
#     \frac{2y^3 - xy^2 + x^3}{x - y} \\ \\
# \end{gather*}

# %% [markdown]
# > 4. Find the quotient.
#
# \begin{gather*}
#     \frac{6x^2 - xy + 2y^2}{2x - y} \\ \\
# \end{gather*}

# %% [markdown]
# > 5. In words, what’s the first question we should ask when solving this long division problem?
#
# \begin{gather*}
#     2x + 3y \ | \ \overline{6x^4 - x^2y + xy^2 + 4y^4}
# \end{gather*}

# %% [markdown]
# > 6. Find the quotient.
#
# \begin{gather*}
#     (y^2 + xy - 3x^2) \div (y + x) \\ \\
# \end{gather*}

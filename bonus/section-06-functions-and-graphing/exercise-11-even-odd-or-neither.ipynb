# %% [markdown]
# ## Exercise 11: Even, Odd, or Neither

# %% [markdown]
# > 1. Is the function even, odd, or neither?
#
# \begin{gather*}
#     f(x) = − x^5 + 2x^2 − 1 \\ \\
# \end{gather*}

# %% [markdown]
# > 2. Describe the symmetry of an even function, and give an example of
# an even function.

# %% [markdown]
# > 3. Determine whether the graph represents a function that’s even, odd,
# or neither.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 4. Determine whether the graph represents a function that’s even, odd,
# or neither.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 5. Is the function even, odd, or neither?
#
# \begin{gather*}
#     h(x) = x^3 − 3x \\ \\
# \end{gather*}

# %% [markdown]
# > 6. Is the function even, odd, or neither?
#
# \begin{gather*}
#     (−2,3), (−1,0), (0, − 1), (1,0), (2,3) \\ \\
# \end{gather*}

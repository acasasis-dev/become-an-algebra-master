# %% [markdown]
# ## Exercise 2: Slope

# %% [markdown]
# > 1. What is the slope of the line?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 2. What direction is an undefined slope: horizontal or vertical? Use the formula for the slope to explain why.

# %% [markdown]
# > 3. What is the slope of the line?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 4. What is the slope of the line that passes through the points $(−1,3)$ and $(4, − 7)$?

# %% [markdown]
# > 5. What is the slope of the line?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 6. Find the slope of the line that passes through $(3,5)$ and $(−1,5)$.
